# %% [markdown]
# ### Bitcoin Prices Over Time

# %%
import pandas as pd
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates

# %%
plt.style.use('seaborn')
plt.figure(figsize=(10,8))

dates = [
    datetime(2019, 5, 24),
    datetime(2019, 5, 25),
    datetime(2019, 5, 26),
    datetime(2019, 5, 27),
    datetime(2019, 5, 28),
    datetime(2019, 5, 29),
    datetime(2019, 5, 30)
]

y = [0,1,3,4,6,5,7]

plt.plot_date(dates, y, linestyle='solid')

# .gcf = get current figure 
# auto format the date on the x axis
plt.gcf().autofmt_xdate()
date_format = mpl_dates.DateFormatter('%b, %d, %Y')

# .gca = get current axis and set major formatter to our selected date format of ('%b, %d, %Y')
plt.gca().xaxis.set_major_formatter(date_format)

# data=pd.read_csv('data8.txt')
# price_data = data['Date']
# price_close = data['Close']

# plt.title('Bitcoin Prices')
# plt.xlabel('Date')
# plt.ylabel('Closing Price')



plt.savefig('plot_08a.png') # save plot to file.png

plt.tight_layout()

plt.show()

# %%
plt.style.use('seaborn')
plt.figure(figsize=(10,8))

data=pd.read_csv('data8.txt')

# code below coverts string date values to "Date" values in order to sort the data by date
data['Date'] = pd.to_datetime(data['Date'])
data.sort_values('Date', inplace=True)

price_data = data['Date']
price_close = data['Close']

plt.plot_date(price_data, price_close, linestyle='solid')

# .gcf = get current figure 
# auto format the date on the x axis
plt.gcf().autofmt_xdate()
date_format = mpl_dates.DateFormatter('%b, %d, %Y')

# .gca = get current axis and set major formatter to our selected date format of ('%b, %d, %Y')
plt.gca().xaxis.set_major_formatter(date_format)


plt.title('Bitcoin Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.savefig('plot_08b.png') # save plot to file.png
plt.tight_layout()

plt.show()
